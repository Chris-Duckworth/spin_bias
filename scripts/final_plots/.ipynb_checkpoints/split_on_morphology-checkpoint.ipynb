# %% [markdown]
# ### split_on_morphology
# - this script finds the trends of $\lambda_R$ vs $M_{halo}$ for individual morphological classifications.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import catalog
import catalog_init 
import catalog_process
import catalog_plot
import copy
import seaborn as sns

# plotting defaults.
from matplotlib.pyplot import rcParams
catalog_plot.default(rcParams)

# %%
basepath = '/Users/chrisduckworth/astronomy/projects/spin_bias/catalogues/'
outpath = '/Users/chrisduckworth/astronomy/projects/spin_bias/plots/final_plots/'

# initiating catalog class objects.
total = catalog.Catalog(basepath, version='mpl9', match_to_lim=True)

# matching to cw definitions and selecting centrals only.
total.match_to_cw(basepath, version='mpl9', sigma=3)
total_cen = copy.deepcopy(total) 
total_sat = copy.deepcopy(total)

total_cen.group_membership(sel='cen', group_cat='lim') 
total_sat.group_membership(sel='sat', group_cat='lim')

# %%
# creating copies of these objects and cutting on morphology.
ltgs = copy.deepcopy(total) 
ltgs_cen = copy.deepcopy(total_cen)
ltgs_sat = copy.deepcopy(total_sat)

ltgs.select_morphology('ltg')
ltgs_cen.select_morphology('ltg')
ltgs_sat.select_morphology('ltg')

# now for s0sa 
s0sa = copy.deepcopy(total) 
s0sa_cen = copy.deepcopy(total_cen)
s0sa_sat = copy.deepcopy(total_sat)

s0sa.select_morphology('s0sa')
s0sa_cen.select_morphology('s0sa')
s0sa_sat.select_morphology('s0sa')

# now for sbsds
sbsd = copy.deepcopy(total) 
sbsd_cen = copy.deepcopy(total_cen)
sbsd_sat = copy.deepcopy(total_sat)

sbsd.select_morphology('sbsd')
sbsd_cen.select_morphology('sbsd')
sbsd_sat.select_morphology('sbsd')

# etgs
etgs = copy.deepcopy(total) 
etgs_cen = copy.deepcopy(total_cen)
etgs_sat = copy.deepcopy(total_sat)

etgs.select_morphology('etg')
etgs_cen.select_morphology('etg')
etgs_sat.select_morphology('etg')

# unclassified
unclassified = copy.deepcopy(total) 
unclassified_cen = copy.deepcopy(total_cen)
unclassified_sat = copy.deepcopy(total_sat)

unclassified.select_morphology('unclassified')
unclassified_cen.select_morphology('unclassified')
unclassified_sat.select_morphology('unclassified')

# %% [markdown]
# ### Creating three panel; all, centrals and satellites.
# - plotting as a function of $\mathrm{M_{halo}}$

# %%
z_percentiles = np.array([0]) 

fig, ax = plt.subplots(1, 3, figsize=(21, 5), sharex='row', sharey='all')

# all galaxies
x_bins = np.array([11.5, 12, 12.5, 13, 13.5, 14])

etgs.plot_scatter("log_halo_mass", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa.plot_scatter("log_halo_mass", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd.plot_scatter("log_halo_mass", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
#unclassified.plot_scatter("log_halo_mass", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'ETGs', ax[0], colors=['crimson'])
ltgs.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'LTGs', ax[0], colors=['darkblue'])
s0sa.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'S0-Sas', ax[0], colors=['purple'])
sbsd.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'Sb-Sds', ax[0], colors=['dodgerblue'])
unclassified.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'Unclassified', ax[0], colors=['orange'])

# centrals only
x_bins = np.array([11.5, 12, 12.5, 13, 13.5])

etgs_cen.plot_scatter("log_halo_mass", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_cen.plot_scatter("log_halo_mass", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_cen.plot_scatter("log_halo_mass", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
#unclassified_cen.plot_scatter("log_halo_mass", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'ETGs', ax[1], colors=['crimson'])
ltgs_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'LTGs', ax[1], colors=['darkblue'])
s0sa_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'S0-Sas', ax[1], colors=['purple'])
sbsd_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'Sb-Sds', ax[1], colors=['dodgerblue'])
unclassified_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'Unclassified', ax[1], colors=['orange'])

# satellites only
x_bins = np.array([12, 12.5, 13, 13.5, 14])

etgs_sat.plot_scatter("log_halo_mass", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_sat.plot_scatter("log_halo_mass", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_sat.plot_scatter("log_halo_mass", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
#unclassified_sat.plot_scatter("log_halo_mass", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'ETGs', ax[2], colors=['crimson'])
ltgs_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'LTGs', ax[2], colors=['darkblue'])
s0sa_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'S0-Sas', ax[2], colors=['purple'])
sbsd_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'Sb-Sds', ax[2], colors=['dodgerblue'])
unclassified_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "nsa_elpetro_mass", x_bins, z_percentiles, 'Unclassified', ax[2], colors=['orange'])


titles = ['All galaxies', 'Centrals', 'Satellites']
for ind, a in enumerate(ax):
    a.set_title(titles[ind], fontsize=20)
    a.set_xlabel("$\mathrm{log_{10}(M_{halo} \; [M_{\odot}])}$", fontsize=16)

ax[0].legend(frameon=False, fontsize=14, ncol=3)
ax[0].set_xlim([11.2, 15.1])
ax[0].set_ylim([0, 1])
ax[0].set_ylabel("$\mathrm{\lambda_R}$", fontsize=20)
fig.subplots_adjust(wspace=0, hspace=0)
plt.show()
#plt.savefig(outpath+'morphology_lambdaR_mhalo.pdf', bbox_inches='tight', format='pdf')

# %% [markdown]
# ### downsampling on the scatter and reformating.

# %%
size = 100
num = 300
alpha = 0.65
z_percentiles = np.array([0]) 

fig, ax = plt.subplots(1, 3, figsize=(21, 5), sharex='row', sharey='all')

# all galaxies
x_bins = np.array([12, 12.5, 13, 13.5, 14])
etgs_ds = etgs.df.sample(n=num)
s0sa_ds = s0sa.df.sample(n=num)
sbsd_ds = sbsd.df.sample(n=num)
unclassified_ds = unclassified.df.sample(n=num)

ax[0].scatter(etgs_ds.log_halo_mass, etgs_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='crimson')
ax[0].scatter(s0sa_ds.log_halo_mass, s0sa_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='seagreen')
ax[0].scatter(sbsd_ds.log_halo_mass, sbsd_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='dodgerblue')

etgs.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'ETGs', ax[0], colors=['crimson'])
ltgs.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'LTGs', ax[0], colors=['midnightblue'])
s0sa.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'S0-Sas', ax[0], colors=['seagreen'])
sbsd.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Sb-Sds', ax[0], colors=['dodgerblue'])
unclassified.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Unclassified', ax[0], colors=['orange'])

# centrals only
x_bins = np.array([12, 12.5, 13, 13.5, 14])
etgs_cen_ds = etgs_cen.df.sample(n=num)
s0sa_cen_ds = s0sa_cen.df.sample(n=num)
sbsd_cen_ds = sbsd_cen.df.sample(n=num)

ax[1].scatter(etgs_cen_ds.log_halo_mass, etgs_cen_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='crimson')
ax[1].scatter(s0sa_cen_ds.log_halo_mass, s0sa_cen_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='seagreen')
ax[1].scatter(sbsd_cen_ds.log_halo_mass, sbsd_cen_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='dodgerblue')

etgs_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'ETGs', ax[1], colors=['crimson'])
ltgs_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'LTGs', ax[1], colors=['darkblue'])
s0sa_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'S0-Sas', ax[1], colors=['seagreen'])
sbsd_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Sb-Sds', ax[1], colors=['dodgerblue'])
unclassified_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Unclassified', ax[1], colors=['orange'])

# satellites only
x_bins = np.array([12, 12.5, 13, 13.5, 14])
etgs_sat_ds = etgs_sat.df.sample(n=num)
s0sa_sat_ds = s0sa_sat.df.sample(n=num)
sbsd_sat_ds = sbsd_sat.df.sample(n=num)

ax[2].scatter(etgs_sat_ds.log_halo_mass, etgs_sat_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='crimson')
ax[2].scatter(s0sa_sat_ds.log_halo_mass, s0sa_sat_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='seagreen')
ax[2].scatter(sbsd_sat_ds.log_halo_mass, sbsd_sat_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='dodgerblue')

etgs_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'ETGs', ax[2], colors=['crimson'])
ltgs_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'LTGs', ax[2], colors=['darkblue'])
s0sa_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'S0-Sas', ax[2], colors=['seagreen'])
sbsd_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Sb-Sds', ax[2], colors=['dodgerblue'])
unclassified_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Unclassified', ax[2], colors=['orange'])

titles = ['All galaxies', 'Centrals', 'Satellites']
for ind, a in enumerate(ax):
    a.set_title(titles[ind], fontsize=20)
    a.set_xlabel("$\mathrm{log_{10}(M_{stel} \; [M_{\odot}])}$", fontsize=16)

ax[0].legend(frameon=False, fontsize=14, ncol=3)
ax[0].set_xlim([11.1, 15.1])
ax[0].set_ylim([0, 1.2])
ax[0].set_ylabel("$\mathrm{\lambda_R}$", fontsize=20)
fig.subplots_adjust(wspace=0, hspace=0)
plt.savefig(outpath+'morphology_lambdaR_mhalo_scatter_downsample300.pdf', bbox_inches='tight', format='pdf')

# %%
size = 5
z_percentiles = np.array([0]) 

fig, ax = plt.subplots(1, 3, figsize=(21, 5), sharex='row', sharey='all')

# all galaxies
x_bins = np.array([11.5, 12, 12.5, 13, 13.5, 14])

# plotting contours.
sns.kdeplot(etgs.df.log_halo_mass, etgs.df.Lambda_Re, ax=ax[0], cmap="Reds", shade=True, shade_lowest=False, n_levels=7, alpha=1)
sns.kdeplot(s0sa.df.log_halo_mass, s0sa.df.Lambda_Re, ax=ax[0], cmap="Greens", shade=True, shade_lowest=False, n_levels=7, alpha=0.8)
sns.kdeplot(sbsd.df.log_halo_mass, sbsd.df.Lambda_Re, ax=ax[0], cmap="Blues", shade=True, shade_lowest=False, n_levels=7, alpha=0.6)
sns.kdeplot(unclassified.df.log_halo_mass, unclassified.df.Lambda_Re, ax=ax[0], cmap="Oranges", shade=True, shade_lowest=False, n_levels=7, alpha=0.4)

etgs.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'ETGs', ax[0], colors=['crimson'])
ltgs.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'LTGs', ax[0], colors=['midnightblue'])
s0sa.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'S0-Sas', ax[0], colors=['seagreen'])
sbsd.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Sb-Sds', ax[0], colors=['dodgerblue'])
unclassified.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Unclassified', ax[0], colors=['orange'])


# centrals only
x_bins = np.array([11.5, 12, 12.5, 13, 13.5, 14])

sns.kdeplot(etgs_cen.df.log_halo_mass, etgs_cen.df.Lambda_Re, ax=ax[1], cmap="Reds", shade=True, shade_lowest=False, n_levels=7, alpha=1)
sns.kdeplot(s0sa_cen.df.log_halo_mass, s0sa_cen.df.Lambda_Re, ax=ax[1], cmap="Greens", shade=True, shade_lowest=False, n_levels=7, alpha=0.8)
sns.kdeplot(sbsd_cen.df.log_halo_mass, sbsd_cen.df.Lambda_Re, ax=ax[1], cmap="Blues", shade=True, shade_lowest=False, n_levels=7, alpha=0.6)
sns.kdeplot(unclassified_cen.df.log_halo_mass, unclassified_cen.df.Lambda_Re, ax=ax[1], cmap="Oranges", shade=True, shade_lowest=False, n_levels=7, alpha=0.4)

etgs_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'ETGs', ax[1], colors=['crimson'])
ltgs_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'LTGs', ax[1], colors=['darkblue'])
s0sa_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'S0-Sas', ax[1], colors=['seagreen'])
sbsd_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Sb-Sds', ax[1], colors=['dodgerblue'])
unclassified_cen.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Unclassified', ax[1], colors=['orange'])

# satellites only
x_bins = np.array([11.5, 12, 12.5, 13, 13.5, 14])

sns.kdeplot(etgs_sat.df.log_halo_mass, etgs_sat.df.Lambda_Re, ax=ax[2], cmap="Reds", shade=True, shade_lowest=False, n_levels=7, alpha=1)
sns.kdeplot(s0sa_sat.df.log_halo_mass, s0sa_sat.df.Lambda_Re, ax=ax[2], cmap="Greens", shade=True, shade_lowest=False, n_levels=7, alpha=0.8)
sns.kdeplot(sbsd_sat.df.log_halo_mass, sbsd_sat.df.Lambda_Re, ax=ax[2], cmap="Blues", shade=True, shade_lowest=False, n_levels=7, alpha=0.6)
sns.kdeplot(unclassified_sat.df.log_halo_mass, unclassified_sat.df.Lambda_Re, ax=ax[2], cmap="Oranges", shade=True, shade_lowest=False, n_levels=7, alpha=0.4)

etgs_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'ETGs', ax[2], colors=['crimson'])
ltgs_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'LTGs', ax[2], colors=['darkblue'])
s0sa_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'S0-Sas', ax[2], colors=['seagreen'])
sbsd_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Sb-Sds', ax[2], colors=['dodgerblue'])
unclassified_sat.plot_binned_percentiles_three_props("log_halo_mass", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Unclassified', ax[2], colors=['orange'])

titles = ['All galaxies', 'Centrals', 'Satellites']
for ind, a in enumerate(ax):
    a.set_title(titles[ind], fontsize=20)
    a.set_xlabel("$\mathrm{log_{10}(M_{halo} \; [M_{\odot}])}$", fontsize=16)
    a.set_ylabel(None)

ax[0].legend(frameon=False, fontsize=14, ncol=2, loc='upper left')
ax[0].set_xlim([11.2, 15.1])
ax[0].set_ylim([0, 1])
ax[0].set_ylabel("$\mathrm{\lambda_R}$", fontsize=20)
fig.subplots_adjust(wspace=0, hspace=0)
plt.savefig(outpath+'morphology_lambdaR_mhalo_kde_w_unclassified.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# ### As a function of $\mathrm{M_{stel}}$

# %%
z_percentiles = np.array([0]) 

fig, ax = plt.subplots(1, 3, figsize=(21, 5), sharex='row', sharey='all')

# all galaxies
x_bins = np.array([9, 9.5, 10, 10.5, 11])

etgs.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'ETGs', ax[0], colors=['crimson'])
ltgs.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'LTGs', ax[0], colors=['darkblue'])
s0sa.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'S0-Sas', ax[0], colors=['purple'])
sbsd.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Sb-Sds', ax[0], colors=['dodgerblue'])
unclassified.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Unclassified', ax[0], colors=['orange'])

# centrals only
x_bins = np.array([9, 9.5, 10, 10.5, 11])

etgs_cen.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_cen.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_cen.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified_cen.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'ETGs', ax[1], colors=['crimson'])
ltgs_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'LTGs', ax[1], colors=['darkblue'])
s0sa_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'S0-Sas', ax[1], colors=['purple'])
sbsd_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Sb-Sds', ax[1], colors=['dodgerblue'])
unclassified_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Unclassified', ax[1], colors=['orange'])

# satellites only
x_bins = np.array([9, 9.5, 10, 10.5, 11])

etgs_sat.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_sat.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_sat.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
#unclassified_sat.plot_scatter("nsa_elpetro_mass_logscale", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'ETGs', ax[2], colors=['crimson'])
ltgs_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'LTGs', ax[2], colors=['darkblue'])
s0sa_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'S0-Sas', ax[2], colors=['purple'])
sbsd_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Sb-Sds', ax[2], colors=['dodgerblue'])
unclassified_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Unclassified', ax[2], colors=['orange'])


titles = ['All galaxies', 'Centrals', 'Satellites']
for ind, a in enumerate(ax):
    a.set_title(titles[ind], fontsize=20)
    a.set_xlabel("$\mathrm{log_{10}(M_{stel} \; [M_{\odot}])}$", fontsize=16)

ax[0].legend(frameon=False, fontsize=14, ncol=3)
ax[0].set_xlim([8.5, 11.5])
ax[0].set_ylim([0, 1])
ax[0].set_ylabel("$\mathrm{\lambda_R}$", fontsize=20)
fig.subplots_adjust(wspace=0, hspace=0)
#plt.savefig(outpath+'morphology_lambdaR_mstel.pdf', bbox_inches='tight', format='pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-25917ac7050b> in <module>
# ----> 1 z_percentiles = np.array([0])
#       2
#       3 fig, ax = plt.subplots(1, 3, figsize=(21, 5), sharex='row', sharey='all')
#       4
#       5 # all galaxies
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### testing downsampling on the scatter and reformating

# %%
size = 100
num = 300
alpha = 0.65
z_percentiles = np.array([0]) 

fig, ax = plt.subplots(1, 3, figsize=(21, 5), sharex='row', sharey='all')

# all galaxies
x_bins = np.array([9, 9.5, 10, 10.5, 11])
etgs_ds = etgs.df.sample(n=num)
s0sa_ds = s0sa.df.sample(n=num)
sbsd_ds = sbsd.df.sample(n=num)
unclassified_ds = unclassified.df.sample(n=num)

ax[0].scatter(etgs_ds.nsa_elpetro_mass_logscale, etgs_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='crimson')
ax[0].scatter(s0sa_ds.nsa_elpetro_mass_logscale, s0sa_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='seagreen')
ax[0].scatter(sbsd_ds.nsa_elpetro_mass_logscale, sbsd_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='dodgerblue')

etgs.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'ETGs', ax[0], colors=['crimson'])
ltgs.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'LTGs', ax[0], colors=['midnightblue'])
s0sa.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'S0-Sas', ax[0], colors=['seagreen'])
sbsd.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Sb-Sds', ax[0], colors=['dodgerblue'])
unclassified.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "log_halo_mass", x_bins, z_percentiles, 'Unclassified', ax[0], colors=['orange'])

# centrals only
x_bins = np.array([9, 9.5, 10, 10.5, 11])
etgs_cen_ds = etgs_cen.df.sample(n=num)
s0sa_cen_ds = s0sa_cen.df.sample(n=num)
sbsd_cen_ds = sbsd_cen.df.sample(n=num)

ax[1].scatter(etgs_cen_ds.nsa_elpetro_mass_logscale, etgs_cen_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='crimson')
ax[1].scatter(s0sa_cen_ds.nsa_elpetro_mass_logscale, s0sa_cen_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='seagreen')
ax[1].scatter(sbsd_cen_ds.nsa_elpetro_mass_logscale, sbsd_cen_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='dodgerblue')

etgs_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'ETGs', ax[1], colors=['crimson'])
ltgs_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'LTGs', ax[1], colors=['darkblue'])
s0sa_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'S0-Sas', ax[1], colors=['seagreen'])
sbsd_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Sb-Sds', ax[1], colors=['dodgerblue'])
unclassified_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Unclassified', ax[1], colors=['orange'])

# satellites only
x_bins = np.array([9, 9.5, 10, 10.5, 11])
etgs_sat_ds = etgs_sat.df.sample(n=num)
s0sa_sat_ds = s0sa_sat.df.sample(n=num)
sbsd_sat_ds = sbsd_sat.df.sample(n=num)

ax[2].scatter(etgs_sat_ds.nsa_elpetro_mass_logscale, etgs_sat_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='crimson')
ax[2].scatter(s0sa_sat_ds.nsa_elpetro_mass_logscale, s0sa_sat_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='seagreen')
ax[2].scatter(sbsd_sat_ds.nsa_elpetro_mass_logscale, sbsd_sat_ds.Lambda_Re, marker='o', linestyle='None', alpha=alpha, s=size, edgecolors='k', color='dodgerblue')

etgs_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'ETGs', ax[2], colors=['crimson'])
ltgs_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'LTGs', ax[2], colors=['darkblue'])
s0sa_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'S0-Sas', ax[2], colors=['seagreen'])
sbsd_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Sb-Sds', ax[2], colors=['dodgerblue'])
unclassified_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Unclassified', ax[2], colors=['orange'])


titles = ['All galaxies', 'Centrals', 'Satellites']
for ind, a in enumerate(ax):
    a.set_title(titles[ind], fontsize=20)
    a.set_xlabel("$\mathrm{log_{10}(M_{stel} \; [M_{\odot}])}$", fontsize=16)

ax[0].legend(frameon=False, fontsize=14, ncol=3)
ax[0].set_xlim([8.5, 11.49])
ax[0].set_ylim([0, 1.2])
ax[0].set_ylabel("$\mathrm{\lambda_R}$", fontsize=20)
fig.subplots_adjust(wspace=0, hspace=0)
plt.savefig(outpath+'morphology_lambdaR_mstel_scatter_downsample300.pdf', bbox_inches='tight', format='pdf')
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /opt/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
size = 5
z_percentiles = np.array([0]) 

fig, ax = plt.subplots(1, 3, figsize=(21, 5), sharex='row', sharey='all')

# all galaxies
x_bins = np.array([9, 9.5, 10, 10.5, 11])

# plotting contours.
sns.kdeplot(etgs.df.nsa_elpetro_mass_logscale, etgs.df.Lambda_Re, ax=ax[0], cmap="Reds", shade=True, shade_lowest=False, n_levels=7, alpha=1)
sns.kdeplot(s0sa.df.nsa_elpetro_mass_logscale, s0sa.df.Lambda_Re, ax=ax[0], cmap="Greens", shade=True, shade_lowest=False, n_levels=7, alpha=0.8)
sns.kdeplot(sbsd.df.nsa_elpetro_mass_logscale, sbsd.df.Lambda_Re, ax=ax[0], cmap="Blues", shade=True, shade_lowest=False, n_levels=7, alpha=0.6)
#sns.kdeplot(unclassified.df.nsa_elpetro_mass_logscale, unclassified.df.Lambda_Re, ax=ax[0], cmap="Oranges", shade=True, shade_lowest=False, n_levels=7, alpha=0.4)

etgs.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'ETGs', ax[0], colors=['crimson'])
ltgs.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'LTGs', ax[0], colors=['midnightblue'])
s0sa.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'S0-Sas', ax[0], colors=['seagreen'])
sbsd.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Sb-Sds', ax[0], colors=['dodgerblue'])
unclassified.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Unclassified', ax[0], colors=['orange'])


# centrals only
x_bins = np.array([9, 9.5, 10, 10.5, 11])

sns.kdeplot(etgs_cen.df.nsa_elpetro_mass_logscale, etgs_cen.df.Lambda_Re, ax=ax[1], cmap="Reds", shade=True, shade_lowest=False, n_levels=7, alpha=1)
sns.kdeplot(s0sa_cen.df.nsa_elpetro_mass_logscale, s0sa_cen.df.Lambda_Re, ax=ax[1], cmap="Greens", shade=True, shade_lowest=False, n_levels=7, alpha=0.8)
sns.kdeplot(sbsd_cen.df.nsa_elpetro_mass_logscale, sbsd_cen.df.Lambda_Re, ax=ax[1], cmap="Blues", shade=True, shade_lowest=False, n_levels=7, alpha=0.6)
#sns.kdeplot(unclassified_cen.df.nsa_elpetro_mass_logscale, unclassified_cen.df.Lambda_Re, ax=ax[1], cmap="Oranges", shade=True, shade_lowest=False, n_levels=7, alpha=0.4)

etgs_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'ETGs', ax[1], colors=['crimson'])
ltgs_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'LTGs', ax[1], colors=['darkblue'])
s0sa_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'S0-Sas', ax[1], colors=['seagreen'])
sbsd_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Sb-Sds', ax[1], colors=['dodgerblue'])
unclassified_cen.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Unclassified', ax[1], colors=['orange'])

# satellites only
x_bins = np.array([9, 9.5, 10, 10.5, 11])

sns.kdeplot(etgs_sat.df.nsa_elpetro_mass_logscale, etgs_sat.df.Lambda_Re, ax=ax[2], cmap="Reds", shade=True, shade_lowest=False, n_levels=7, alpha=1)
sns.kdeplot(s0sa_sat.df.nsa_elpetro_mass_logscale, s0sa_sat.df.Lambda_Re, ax=ax[2], cmap="Greens", shade=True, shade_lowest=False, n_levels=7, alpha=0.8)
sns.kdeplot(sbsd_sat.df.nsa_elpetro_mass_logscale, sbsd_sat.df.Lambda_Re, ax=ax[2], cmap="Blues", shade=True, shade_lowest=False, n_levels=7, alpha=0.6)
#sns.kdeplot(unclassified_sat.df.nsa_elpetro_mass_logscale, unclassified_sat.df.Lambda_Re, ax=ax[2], cmap="Oranges", shade=True, shade_lowest=False, n_levels=7, alpha=0.4)

etgs_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'ETGs', ax[2], colors=['crimson'])
ltgs_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'LTGs', ax[2], colors=['darkblue'])
s0sa_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'S0-Sas', ax[2], colors=['seagreen'])
sbsd_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Sb-Sds', ax[2], colors=['dodgerblue'])
unclassified_sat.plot_binned_percentiles_three_props("nsa_elpetro_mass_logscale", "Lambda_Re", "nsa_elpetro_mass_logscale", x_bins, z_percentiles, 'Unclassified', ax[2], colors=['orange'])

titles = ['All galaxies', 'Centrals', 'Satellites']
for ind, a in enumerate(ax):
    a.set_title(titles[ind], fontsize=20)
    a.set_xlabel("$\mathrm{log_{10}(M_{stel} \; [M_{\odot}])}$", fontsize=16)
    a.set_ylabel(None)

ax[0].legend(frameon=False, fontsize=14, ncol=2, loc='upper left')
ax[0].set_xlim([8.5, 11.49])
ax[0].set_ylim([0, 1])
ax[0].set_ylabel("$\mathrm{\lambda_R}$", fontsize=20)
fig.subplots_adjust(wspace=0, hspace=0)
plt.savefig(outpath+'morphology_lambdaR_mstel_kde_wo_unclassified.pdf', format='pdf', bbox_inches='tight')
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /opt/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### As a function of $D_{node}$

# %%
z_percentiles = np.array([0]) 

fig, ax = plt.subplots(1, 3, figsize=(21, 5), sharex='row', sharey='all')

# all galaxies
x_bins = np.percentile(total.df.log_dnode_norm.values, np.linspace(10, 90, 9))

etgs.plot_scatter("log_dnode_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa.plot_scatter("log_dnode_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd.plot_scatter("log_dnode_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified.plot_scatter("log_dnode_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'ETGs', ax[0], colors=['crimson'])
ltgs.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'LTGs', ax[0], colors=['darkblue'])
s0sa.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'S0-Sas', ax[0], colors=['purple'])
sbsd.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'Sb-Sds', ax[0], colors=['dodgerblue'])
unclassified.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'Unclassified', ax[0], colors=['orange'])

# centrals only
x_bins = np.percentile(total_cen.df.log_dnode_norm.values, np.linspace(10, 90, 9))

etgs_cen.plot_scatter("log_dnode_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_cen.plot_scatter("log_dnode_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_cen.plot_scatter("log_dnode_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified_cen.plot_scatter("log_dnode_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_cen.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'ETGs', ax[1], colors=['crimson'])
ltgs_cen.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'LTGs', ax[1], colors=['darkblue'])
s0sa_cen.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'S0-Sas', ax[1], colors=['purple'])
sbsd_cen.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'Sb-Sds', ax[1], colors=['dodgerblue'])
unclassified_cen.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'Unclassified', ax[1], colors=['orange'])

# satellites only
x_bins = np.percentile(total_sat.df.log_dnode_norm.values, np.linspace(11, 90, 9))

etgs_sat.plot_scatter("log_dnode_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_sat.plot_scatter("log_dnode_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_sat.plot_scatter("log_dnode_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified_sat.plot_scatter("log_dnode_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_sat.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'ETGs', ax[2], colors=['crimson'])
ltgs_sat.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'LTGs', ax[2], colors=['darkblue'])
s0sa_sat.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'S0-Sas', ax[2], colors=['purple'])
sbsd_sat.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'Sb-Sds', ax[2], colors=['dodgerblue'])
unclassified_sat.plot_binned_percentiles_three_props("log_dnode_norm", "Lambda_Re", "log_dnode_norm", x_bins, z_percentiles, 'Unclassified', ax[2], colors=['orange'])


titles = ['All galaxies', 'Centrals', 'Satellites']
for ind, a in enumerate(ax):
    a.set_title(titles[ind], fontsize=20)
    a.set_xlabel("$\mathrm{log_{10}(D_{node} / \langle D_{z} \\rangle )}$", fontsize=16)

ax[0].legend(frameon=False, fontsize=14, ncol=3)
ax[0].set_xlim([-2.2, 0.75])
ax[0].set_ylim([0, 1])
ax[0].set_ylabel("$\mathrm{\lambda_R}$", fontsize=20)
fig.subplots_adjust(wspace=0, hspace=0)
plt.savefig(outpath+'morphology_lambdaR_dnode.pdf', bbox_inches='tight', format='pdf')

# %% [markdown]
# ### As a function of $D_{skel}$

# %%
z_percentiles = np.array([0]) 

fig, ax = plt.subplots(1, 3, figsize=(21, 5), sharex='row', sharey='all')

# all galaxies
x_bins = np.percentile(total.df.log_dskel_norm.values, np.linspace(10, 90, 9))

etgs.plot_scatter("log_dskel_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa.plot_scatter("log_dskel_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd.plot_scatter("log_dskel_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified.plot_scatter("log_dskel_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'ETGs', ax[0], colors=['crimson'])
ltgs.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'LTGs', ax[0], colors=['darkblue'])
s0sa.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'S0-Sas', ax[0], colors=['purple'])
sbsd.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Sb-Sds', ax[0], colors=['dodgerblue'])
unclassified.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Unclassified', ax[0], colors=['orange'])

# centrals only
x_bins = np.percentile(total_cen.df.log_dskel_norm.values, np.linspace(10, 90, 9))

etgs_cen.plot_scatter("log_dskel_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_cen.plot_scatter("log_dskel_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_cen.plot_scatter("log_dskel_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified_cen.plot_scatter("log_dskel_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_cen.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'ETGs', ax[1], colors=['crimson'])
ltgs_cen.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'LTGs', ax[1], colors=['darkblue'])
s0sa_cen.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'S0-Sas', ax[1], colors=['purple'])
sbsd_cen.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Sb-Sds', ax[1], colors=['dodgerblue'])
unclassified_cen.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Unclassified', ax[1], colors=['orange'])

# satellites only
x_bins = np.percentile(total_sat.df.log_dskel_norm.values, np.linspace(11, 90, 9))

etgs_sat.plot_scatter("log_dskel_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_sat.plot_scatter("log_dskel_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_sat.plot_scatter("log_dskel_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified_sat.plot_scatter("log_dskel_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_sat.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'ETGs', ax[2], colors=['crimson'])
ltgs_sat.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'LTGs', ax[2], colors=['darkblue'])
s0sa_sat.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'S0-Sas', ax[2], colors=['purple'])
sbsd_sat.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Sb-Sds', ax[2], colors=['dodgerblue'])
unclassified_sat.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Unclassified', ax[2], colors=['orange'])

titles = ['All galaxies', 'Centrals', 'Satellites']
for ind, a in enumerate(ax):
    a.set_title(titles[ind], fontsize=20)
    a.set_xlabel("$\mathrm{log_{10}(D_{skel} / \langle D_{z} \\rangle )}$", fontsize=16)

ax[0].legend(frameon=False, fontsize=14, ncol=3)
ax[0].set_xlim([-1.9, 0.49])
ax[0].set_ylim([0, 1])
ax[0].set_ylabel("$\mathrm{\lambda_R}$", fontsize=20)
fig.subplots_adjust(wspace=0, hspace=0)
plt.savefig(outpath+'morphology_lambdaR_dskel.pdf', bbox_inches='tight', format='pdf')

# %% [markdown]
# ### As a function of $D_{skel}$ with $D_{node}$ removed

# %%
node_dist = 1

ltgs_filament = copy.deepcopy(ltgs) 
ltgs_cen_filament = copy.deepcopy(ltgs_cen)
ltgs_sat_filament = copy.deepcopy(ltgs_sat)
ltgs_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)
ltgs_cen_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)
ltgs_sat_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)

s0sa_filament = copy.deepcopy(s0sa) 
s0sa_cen_filament = copy.deepcopy(s0sa_cen)
s0sa_sat_filament = copy.deepcopy(s0sa_sat)
s0sa_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)
s0sa_cen_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)
s0sa_sat_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)

sbsd_filament = copy.deepcopy(sbsd) 
sbsd_cen_filament = copy.deepcopy(sbsd_cen)
sbsd_sat_filament = copy.deepcopy(sbsd_sat)
sbsd_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)
sbsd_cen_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)
sbsd_sat_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)

etgs_filament = copy.deepcopy(etgs) 
etgs_cen_filament = copy.deepcopy(etgs_cen)
etgs_sat_filament = copy.deepcopy(etgs_sat)
etgs_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)
etgs_cen_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)
etgs_sat_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)

unclassified_filament = copy.deepcopy(unclassified) 
unclassified_cen_filament = copy.deepcopy(unclassified_cen)
unclassified_sat_filament = copy.deepcopy(unclassified_sat)
unclassified_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)
unclassified_cen_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)
unclassified_sat_filament.select_cw_enviro(feature='no_node', node_dist=node_dist)

# %%
z_percentiles = np.array([0]) 

fig, ax = plt.subplots(1, 3, figsize=(21, 5), sharex='row', sharey='all')

# all galaxies
x_bins = np.percentile(total.df.log_dskel_norm.values, np.linspace(20, 80, 6))

etgs_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[0], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'ETGs', ax[0], colors=['crimson'])
ltgs_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'LTGs', ax[0], colors=['darkblue'])
s0sa_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'S0-Sas', ax[0], colors=['purple'])
sbsd_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Sb-Sds', ax[0], colors=['dodgerblue'])
unclassified_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Unclassified', ax[0], colors=['orange'])

# centrals only
x_bins = np.percentile(total_cen.df.log_dskel_norm.values, np.linspace(20, 80, 6))

etgs_cen_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_cen_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_cen_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified_cen_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[1], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_cen_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'ETGs', ax[1], colors=['crimson'])
ltgs_cen_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'LTGs', ax[1], colors=['darkblue'])
s0sa_cen_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'S0-Sas', ax[1], colors=['purple'])
sbsd_cen_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Sb-Sds', ax[1], colors=['dodgerblue'])
unclassified_cen_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Unclassified', ax[1], colors=['orange'])

# satellites only
x_bins = np.percentile(total_sat.df.log_dskel_norm.values, np.linspace(20, 80, 6))

etgs_sat_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='crimson')
s0sa_sat_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='purple')
sbsd_sat_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.08, markersize=10, color='dodgerblue')
unclassified_sat_filament.plot_scatter("log_dskel_norm", "Lambda_Re", ax[2], marker='o', linestyle='None', alpha=0.1, markersize=10, color='orange')

etgs_sat_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'ETGs', ax[2], colors=['crimson'])
ltgs_sat_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'LTGs', ax[2], colors=['darkblue'])
s0sa_sat_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'S0-Sas', ax[2], colors=['purple'])
sbsd_sat_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Sb-Sds', ax[2], colors=['dodgerblue'])
unclassified_sat_filament.plot_binned_percentiles_three_props("log_dskel_norm", "Lambda_Re", "log_dskel_norm", x_bins, z_percentiles, 'Unclassified', ax[2], colors=['orange'])

titles = ['All galaxies', 'Centrals', 'Satellites']
for ind, a in enumerate(ax):
    a.set_title(titles[ind], fontsize=20)
    a.set_xlabel("$\mathrm{log_{10}(D_{skel} / \langle D_{z} \\rangle )}$", fontsize=16)

ax[0].legend(frameon=False, fontsize=14, ncol=3)
ax[0].set_xlim([-1.6, 0.49])
ax[0].set_ylim([0, 1])
ax[0].set_ylabel("$\mathrm{\lambda_R}$", fontsize=20)
fig.subplots_adjust(wspace=0, hspace=0)
plt.savefig(outpath+'morphology_lambdaR_dskel_no_dnode.pdf', bbox_inches='tight', format='pdf')
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /opt/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
