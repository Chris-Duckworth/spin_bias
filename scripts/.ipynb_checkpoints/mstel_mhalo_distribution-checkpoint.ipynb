# %% [markdown]
# ### mstel_mhalo_distribution
# - This script looks at the distribution of mstel vs mhalo and then colours on various properties.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import catalog
import catalog_init 
import catalog_process
import catalog_plot
import copy

import imp 
imp.reload(catalog)
imp.reload(catalog_plot)
imp.reload(catalog_process)
imp.reload(catalog_init)

# plotting defaults.
from matplotlib.pyplot import rcParams
catalog_plot.default(rcParams)

# %%
basepath = '/Users/chrisduckworth/astronomy/projects/spin_bias/catalogues/'
outpath = '/Users/chrisduckworth/astronomy/projects/spin_bias/plots/mstel_mhalo_distributions/'

# initiating catalog class objects.
total = catalog.Catalog(basepath)

# matching to cw definitions and selecting centrals only.
total.match_to_cw(basepath)
total.remove_satellites(keep_zero_mass=False) # keeping 100 galaxies without halo mass definitions (but have central definitions etc.)

# creating copies of these objects and cutting on morphology.
ltgs = copy.deepcopy(total) 
ltgs.select_morphology('ltg')

etgs = copy.deepcopy(total) 
etgs.select_morphology('etg')

unclassified = copy.deepcopy(total)
unclassified.select_morphology('unclassified')
# Out:
# /Users/chrisduckworth/astronomy/projects/spin_bias/scripts/catalog_init.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tab['stellar_to_halo_ratio'] = np.log10(tab['nsa_elpetro_mass']) -  tab['halo_mass_stel']

# %%
fig, ax = plt.subplots(1, figsize=(6,4))

total.plot_hexbin('halo_mass_stel', 'nsa_elpetro_mass_logscale', ax, C=total.df.lambda_re.values, gridsize=40, cmap='bone_r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-350a902d7183> in <module>
#       1 fig, ax = plt.subplots(1, figsize=(6,4))
#       2
# ----> 3 total.plot_hexbin('halo_mass_stel', 'nsa_elpetro_mass_logscale', ax, C=total.df.lambda_re.values, gridsize=40, cmap='bone_r')
#
# ~/astronomy/projects/spin_bias/scripts/catalog.py in plot_hexbin(self, x_col, y_col, ax, **kwargs)
#      55         def plot_hexbin(self, x_col, y_col, ax, **kwargs):
#      56                 '''hexbin plot of defined columns'''
# ---> 57                 return catalog_plot.plot_histogram(self.df[x_col].values, self.df[y_col].values, ax, **kwargs)
#      58
#      59         def plot_binned_percentiles_three_props(self, x_col, y_col, z_col, x_bins, z_percentiles, z_percentile_labels, ax, colors=['lightslategrey', 'slateblue', 'dodgerblue', 'rebeccapurple'], extrema=False):
#
# ...

# %%
fig, ax = plt.subplots(1, figsize=(6,4))
hb = ax.hexbin(total.df.halo_mass_stel.values, total.df.nsa_elpetro_mass_logscale.values, C=total.df.lambda_re.values, gridsize=40, cmap='bone_r')

cb = fig.colorbar(hb, ax=ax)
cb.set_label('$\mathrm{\lambda_R}$', fontsize=14)
ax.set_xlabel('$\mathrm{log_{10}(M_{halo}) \; [M_{\odot}]}$', fontsize=14)
ax.set_ylabel('$\mathrm{log_{10}(M_{stel}) \; [M_{\odot}]}$', fontsize=14)
ax.set_ylim([9.5, 11.5])
ax.set_xlim([11.7, 14.5])
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(6,4))

hb = ax.hexbin(total.df.halo_mass_stel.values, total.df.nsa_elpetro_mass_logscale.values, C=total.df.log_dnode_norm.values, gridsize=40, cmap='Reds_r')

cb = fig.colorbar(hb, ax=ax)
cb.set_label('$\mathrm{\lambda_R}$', fontsize=14)
ax.set_xlabel('$\mathrm{log_{10}(M_{halo}) \; [M_{\odot}]}$', fontsize=14)
ax.set_ylabel('$\mathrm{log_{10}(M_{stel}) \; [M_{\odot}]}$', fontsize=14)
ax.set_ylim([9.5, 11.5])
ax.set_xlim([11.7, 14.5])
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(6,4))

hb = ax.hexbin(total.df.halo_mass_stel.values, total.df.nsa_elpetro_mass_logscale.values, C=total.df.log_dskel_norm.values, gridsize=40, cmap='Blues_r')

cb = fig.colorbar(hb, ax=ax)
cb.set_label('$\mathrm{\lambda_R}$', fontsize=14)
ax.set_xlabel('$\mathrm{log_{10}(M_{halo}) \; [M_{\odot}]}$', fontsize=14)
ax.set_ylabel('$\mathrm{log_{10}(M_{stel}) \; [M_{\odot}]}$', fontsize=14)
ax.set_ylim([9.5, 11.5])
ax.set_xlim([11.7, 14.5])
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(6,4))

hb = ax.hexbin(total.df.halo_mass_stel.values, total.df.nsa_elpetro_mass_logscale.values, C=total.df.stellar_to_halo_ratio.values, gridsize=40, cmap='Greys')

cb = fig.colorbar(hb, ax=ax)
cb.set_label('$\mathrm{\lambda_R}$', fontsize=14)
ax.set_xlabel('$\mathrm{log_{10}(M_{halo}) \; [M_{\odot}]}$', fontsize=14)
ax.set_ylabel('$\mathrm{log_{10}(M_{stel}) \; [M_{\odot}]}$', fontsize=14)
ax.set_ylim([9.5, 11.5])
ax.set_xlim([11.7, 14.5])
plt.show()
