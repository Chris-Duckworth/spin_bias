# %% [markdown]
# ### control_comparison
# - this script divides the population into CW environments and then compares to various control samples.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import catalog
import catalog_init 
import catalog_process
import catalog_plot
import copy

# plotting defaults.
from matplotlib.pyplot import rcParams
catalog_plot.default(rcParams)

# %%
basepath = '/Users/chrisduckworth/astronomy/projects/spin_bias/catalogues/'
outpath = '/Users/chrisduckworth/astronomy/projects/spin_bias/plots/control_comparison/'

# initiating catalog class objects.
total = catalog.Catalog(basepath)

# matching to cw definitions and selecting centrals only.
total.match_to_cw(basepath)
total.remove_satellites()

# creating copies of these objects and cutting on morphology.
ltgs = copy.deepcopy(total) 
ltgs.select_morphology('ltg')

etgs = copy.deepcopy(total) 
etgs.select_morphology('etg')

unclassified = copy.deepcopy(total)
unclassified.select_morphology('unclassified')
# Out:
# /Users/chrisduckworth/astronomy/projects/spin_bias/scripts/catalog_init.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tab['stellar_to_halo_ratio'] = np.log10(tab.nsa_elpetro_mass.values) -  tab.halo_mass_stel.values

# %%
# creating close to filament sample and then an inverse catalogue to select mass matched from.
total_filament = copy.deepcopy(total) 
total_filament_residual = copy.deepcopy(total) 

total_filament_residual.select_cw_enviro(feature='filament_residual', node_dist=2, filament_dist=1.5)
total_filament.select_cw_enviro(feature='filament', node_dist=2, filament_dist=1.5)

# creating matched subsample.
total_filament_residual.return_matched_subsample('nsa_elpetro_mass', total_filament.df.nsa_elpetro_mass.values)
# Out:
#       CATALOG_RA_x  CATALOG_DEC_x     NSA_Z MANGAID_x     ID  GalID  \
# 4548    120.866938      25.102683  0.027568  1-604970  34886   8859
# 909     177.844535      53.444189  0.051843  1-150370   6319   4416
# 2047    165.153957      44.097512  0.036487  1-256155  12220  11612
# 882     170.859803      51.719018  0.080108  1-149631   6273  44417
# 2560    203.896532      40.111095  0.054177  1-285729  14141   7396
# ...            ...            ...       ...       ...    ...    ...
# 1108    162.385986      47.933240  0.028056  1-173583   7868   5230
# 866     172.218383      51.000680  0.059411  1-149517   6255  58935
# 3086    116.097926      44.527741  0.049657  1-339028  17148  10352
# 1578    129.594027       4.355985  0.047492  1-213825   9690   9431
# 2918    243.441829      22.919014  0.031916  1-318321  15733   3154
#
#       dtfe_density  dtfe_gauss_3Mpc  dgkernel_9Mpc  dtfe_gauss_9Mpc  ...  \
# 4548      0.008905         0.024984       0.014602         0.015143  ...
# 909       0.083971         0.045788       0.027398         0.025570  ...
# 2047      0.117300         0.033158       0.010879         0.009394  ...
# 882       0.006367         0.021097       0.004394         0.003472  ...
# 2560      0.015693         0.005684       0.007945         0.011392  ...
# ...            ...              ...            ...              ...  ...
# 1108      0.043108         0.023106       0.015017         0.014360  ...
# 866       0.014734         0.005268       0.006612         0.005958  ...
# 3086      0.062314         0.019036       0.009340         0.009011  ...
# 1578      1.348298         0.031888       0.005493         0.005498  ...
# 2918      0.228289         0.118015       0.036373         0.036959  ...
#
#       vel_sigma_re  e_vel_sigma_re  lambda_re  e_lambda_re  plate_y  \
# 4548      0.197456        0.034926   0.165880     0.058682     8940
# 909       0.369528        0.086378   0.663202     0.310049     8995
# 2047      0.332153        0.052180   0.326988     0.102737     8255
# 882       0.396606        0.120245   0.384874     0.233376     8997
# 2560      0.223839        0.104497   0.250879     0.234240     8330
# ...            ...             ...        ...          ...      ...
# 1108      0.260389        0.042363   0.259783     0.084529     8998
# 866       0.375475        0.139176   0.331434     0.245703     8992
# 3086      0.104760        0.102354   0.145649     0.284606     8138
# 1578      0.282371        0.040180   0.287772     0.081897     9511
# 2918      0.368479        0.043869   0.624944     0.148806     9095
#
#       ifudsgn_y  log_dskel_norm  log_dwall_norm  log_dnode_norm  \
# 4548       6102       -0.087980       -0.424518        0.262895
# 909       12705       -0.859041       -0.673848        0.270989
# 2047       1901       -0.440117       -0.291673       -0.048305
# 882        6102        0.455487       -0.905908        0.796939
# 2560       3702        0.305393        0.122848        0.297245
# ...         ...             ...             ...             ...
# 1108       6101        0.378375       -0.780695        0.442440
# 866       12705       -0.174646       -0.386594        0.189034
# 3086       3702       -0.940532       -0.843226       -0.005280
# 1578       3703       -1.001342       -1.676692       -0.371049
# 2918       6102       -0.866361       -0.800438        0.133568
#
#       stellar_to_halo_ratio
# 4548              -1.899796
# 909               -2.355797
# 2047              -1.805861
# 882               -2.046846
# 2560              -2.138833
# ...                     ...
# 1108              -1.717469
# 866               -1.868485
# 3086              -1.957142
# 1578              -2.426943
# 2918              -2.309192
#
# [742 rows x 418 columns]
